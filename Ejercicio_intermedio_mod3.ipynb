# %% [markdown]
# # EJERCICIO INTERMEDIO MÓDULO 3

# %% [markdown]
# 1. Importa Pandas

# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
# pd.set_option('display.max_rows', None) # para poder visualizar todas las columnas de los DataFrames

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt
# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %% [markdown]
# 2. Exploración del conjunto de datos:
#     o Carga el fichero, al cargarlo te aparecerá una columna llamada "Unnamed: 0". Carga el dataset sin que aparezca esta columna. Además realiza un análisis exploratorio que incluya:

# %%
#Abrimos el CSV con los datos

df_spoty = pd.read_csv("Spotify_Youtube.csv", index_col = 0)
df_spoty.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %% [markdown]
# - Cuando leas el fichero, veras que no podemos ver todas las columnas, utiliza el comando correcto para poder visualizarlas todas cuando hacemos un head (ARRIBA)

# %% [markdown]
# - Primeras 5 filas del dataframe

# %%
df_spoty.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %% [markdown]
# - Últimas 5 filas del dataframe

# %%
df_spoty.tail()
# Out:
#             Artist                                        Url_spotify  \
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 Track                           Album  \
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
#       Album_type                                   Uri Danceability Energy  \
# ...

# %% [markdown]
# - 10 filas aleatorias del dataframe

# %%
df_spoty.sample(10)
# Out:
#                         Artist  \
# 2782             Laura Pausini
# 6505   The Cinematic Orchestra
# 17935              Post Malone
# 10147          Yeah Yeah Yeahs
# 19601               Juice WRLD
# 4193            Caetano Veloso
# 8880                     Mario
# 7237                    Rafaga
# 862                     Plan B
# 9134               Rick Astley
#
#                                              Url_spotify  \
# 2782   https://open.spotify.com/artist/2e4nwiX8ZCU09L...
# 6505   https://open.spotify.com/artist/32ogthv0BdaSMP...
# 17935  https://open.spotify.com/artist/246dkjvS1zLTti...
# 10147  https://open.spotify.com/artist/3TNt4aUIxgfy9a...
# 19601  https://open.spotify.com/artist/4MCBfE4596Uoi2...
# 4193   https://open.spotify.com/artist/7HGNYPmbDrMkyl...
# 8880   https://open.spotify.com/artist/20s0P9QLxGqKuC...
# 7237   https://open.spotify.com/artist/0CBKUzrf6yGdTg...
# 862    https://open.spotify.com/artist/2jSGzJw0ebJLu7...
# ...

# %% [markdown]
# - ¿Cuántas filas y columnas tenemos en el dataframe?

# %%
df_spoty.shape
# Out:
# (20718, 27)

# %% [markdown]
# - ¿Cuáles son los tipos de los datos de cada columna del dataframe?

# %%
df_spoty.dtypes
# Out:
# Artist               object
# Url_spotify          object
# Track                object
# Album                object
# Album_type           object
# Uri                  object
# Danceability         object
# Energy               object
# Key                  object
# Loudness             object
# Speechiness          object
# Acousticness         object
# Instrumentalness     object
# Liveness            float64
# Valence             float64
# Tempo               float64
# Duration_ms         float64
# Url_youtube          object
# Title                object
# Channel              object
# Views               float64
# Likes               float64
# Comments            float64
# Description          object
# Licensed             object
# Official_video       object
# Stream              float64
# dtype: object

# %% [markdown]
# - ¿Cuántos valores nulos tenemos por columna?

# %%
df_spoty.isnull().sum()
# Out:
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# Official_video      470
# Stream              576
# dtype: int64

# %% [markdown]
# - ¿Tenemos filas duplicadas en el dataframe?

# %%
df_spoty.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - Muestra los principales estadísticos para las columnas numéricas del dataframe

# %%
df_spoty.describe(include = {np.number})
# Out:
#        danceability        energy           key      loudness   speechiness  \
# count  20716.000000  20716.000000  20716.000000  20716.000000  20716.000000
# mean       0.619777      0.635250      5.300348     -7.671680      0.096456
# std        0.165272      0.214147      3.576449      4.632749      0.111960
# min        0.000000      0.000020      0.000000    -46.251000      0.000000
# 25%        0.518000      0.507000      2.000000     -8.858000      0.035700
# 50%        0.637000      0.666000      5.000000     -6.536000      0.050500
# 75%        0.740250      0.798000      8.000000     -4.931000      0.103000
# max        0.975000      1.000000     11.000000      0.920000      0.964000
#
#        acousticness  instrumentalness      liveness       valence  \
# count  20716.000000      20716.000000  20716.000000  20716.000000
# mean       0.291535          0.055962      0.193521      0.529853
# std        0.286299          0.193262      0.168531      0.245441
# ...

# %% [markdown]
# - Muestra los principales estadísticos para las columnas categóricas del dataframe

# %%
df_spoty.describe(include='object')
# Out:
#           Artist                                        Url_spotify  \
# count      20718                                              20718
# unique      2079                                               2079
# top     Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# freq          10                                                 10
#
#                                             Track          Album Album_type  \
# count                                       20718          20718      20718
# unique                                      17841          11937          3
# top     El Ultimo Adiós - Varios Artistas Version  Greatest Hits      album
# freq                                           24             30      14926
#
#                                          Uri Danceability Energy    Key  \
# count                                  20718        20716  20716  20716
# unique                                 18862          898   1268     12
# ...

# %% [markdown]
# ----------------------------------------------

# %% [markdown]
# 3. Preparación de los datos:
#
#     o Los nombres de las columnas empiezan con mayúsculas, pon todos los nombres de las columnas en minúsculas.

# %%
# Convertir todos los nombres de columnas a minúsculas
df_spoty.columns = df_spoty.columns.str.lower()

# %%
# Visualizo el df para comprobarlo
df_spoty.head(1)
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#             track       album album_type  \
# 0  Feel Good Inc.  Demon Days      album
#
#                                     uri danceability energy  key loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT        0,818  0,705  6,0   -6,679
#
#   speechiness acousticness instrumentalness  liveness  valence    tempo  \
# 0       0,177      0,00836          0,00233     0.613    0.772  138.559
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
#
#                                         title   channel        views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
# ...

# %% [markdown]
# o Haciendo el análisis exploratorio te deberías haber dado cuenta de que algunas de las variables (danceability, energy, key, loudness, speechiness, acousticness,instrumentalness) no son del tipo que deberían. Esto es debido a que los decimales están establecidos como comas y no con puntos. Crea una función que nos permita cambiar esas comas por puntos para que los datos tengan el tipo correcto.
#
#     - Después de haber hecho los cambios, chequea los tipos de datos. ¿Son ya del tipo correcto? En caso de que no, crea otra función o modifica la anterior para que sean de tipo float.

# %%
# Primero hago una lista de las columnas que tienen comas y quiero cambiar por puntos
col_cambio = ["danceability", "energy", "key", "loudness", "speechiness", "acousticness", "instrumentalness"]

def cambio_comas_por_puntos(df, columnas):
    for col in columnas:
        df[col] = df[col].str.replace(",", ".").astype(float)
    return df

# Aplicamos los cambios a nuestro df
df_spoty = cambio_comas_por_puntos(df_spoty, col_cambio)

# %%
# Compruebo el cambio
df_spoty.head(2)
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#              track          album album_type  \
# 0   Feel Good Inc.     Demon Days      album
# 1  Rhinestone Eyes  Plastic Beach      album
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0    -5.815
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1770       0.00836          0.002330    0.6130    0.772  138.559
# 1       0.0302       0.08690          0.000687    0.0463    0.852   92.761
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# ...

# %% [markdown]
# o Hay algunas canciones cuyo título está en mayúsulas. Crea una función para que todos los títulos estén en minúscula. Haz lo mismo para las columnas de "title" y "album".

# %%
# Hago una lista con las columnas que tengo que modificar

col_mayus = ["title", "album", "track"]

def convertir_a_minusculas(df, columnas):
    for col in columnas:
        df[col] = df[col].str.lower()
    return df

# Aplico los cambios a mi df
df_spoty = convertir_a_minusculas(df_spoty, col_mayus)

# %%
# Compruebo el cambio

df_spoty.head(2)
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#              track          album album_type  \
# 0   feel good inc.     demon days      album
# 1  rhinestone eyes  plastic beach      album
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0    -5.815
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1770       0.00836          0.002330    0.6130    0.772  138.559
# 1       0.0302       0.08690          0.000687    0.0463    0.852   92.761
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# ...

# %% [markdown]
# o Algunos de los artistas tienen símbolos raros, en concreto el símbolo $. Crea una función que los reemplaze pos "s"

# %%
df_spoty["artist"] = df_spoty["artist"].str.replace("$", "s")
# Out:
# /tmp/ipykernel_1007/1068543024.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_spoty["artist"] = df_spoty["artist"].str.replace("$", "s")

# %% [markdown]
# ------------------------------------

# %% [markdown]
# 4. Filtrado de datos:
#     o ¿Cuáles son los valores únicos de la columna "album_type"? Crea tres dataframes diferentes, uno para cada tipo de "album_type". ¿Cuántas canciones tenemos en cada tipo?

# %%
# A través del método 'unique' estudiamos los valores únicos de la columna
df_spoty["album_type"].unique()
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
# Creo 3 df con los distintos tipos de álbunes

df_single = df_spoty[df_spoty["album_type"] == "single"] 
df_album = df_spoty[df_spoty["album_type"] == "album"]
df_compilation = df_spoty[df_spoty["album_type"] == "compilation"]

# Para contar el num de canciones que hay en cada uno, utilizo el método len

print(f"Singles: {len(df_single)}")

print(f"Albums: {len(df_album)}")

print(f"Compilations: {len(df_compilation)}")
# Out:
# Singles: 5004
# Albums: 14926
# Compilations: 788

# %%
# Otra forma de hacerlo

df_album.shape[0]
df_single.shape[0]
df_compilation.shape[0]

# %% [markdown]
# o Usando el dataframe de los albumes que hemos creado en el ejercicio anterior. ¿Cuál es la media y la desviación estándar de "danceability", "acousticness" y "speechiness" de
# cada artista?. Muesrtra los resultados en tres dataframes diferentes, uno para cada métrica ("danceability", "acousticness" y "speechiness"). Ordena los resultados de mayor a menor en base a la media.

# %%
# Media y desviación estándar de danceability 
df_danceability = df_album.groupby('artist')['danceability'].agg(['mean', 'std']).sort_values(by='mean', ascending=False)

# Media y desviación estándar de acousticness 
df_acousticness = df_album.groupby('artist')['acousticness'].agg(['mean', 'std']).sort_values(by='mean', ascending=False)

# Media y desviación estándar de speechiness 
df_speechiness = df_album.groupby('artist')['speechiness'].agg(['mean', 'std']).sort_values(by='mean', ascending=False)

print('danceability')
# Out:
# danceability

# %% [markdown]
# o Se quiere estudiar si existe una relación entre la cantidad de visitas que reciben los videos de música de un artista en una plataforma de streaming y la cantidad de likes que
# estos videos obtienen. Por lo tanto, queremos contestar a la siguiente pregunta: ¿Son aquellos artistas que tienen más visitas los que más likes tienen? Para solucionar este
# ejercicio deberéis:
#
#     - Agrupa por artista y calcular la media de visitas y de likes.
#     - Quedate con los 10 artistas que más visitas han tenido.
#     - Quedate con los 10 artistas que más likes han tenido.
#     - BONUS Haced lo mismo para los datos de tipo "single"

# %%
# Calculo la media de visitas y likes
df_artist = df_spoty.groupby('artist').agg({'views': 'mean', 'likes': 'mean'})

# Los 10 artistas con más visitas
top_10_views = df_artist.sort_values(by='views', ascending=False).head(10)

# Los 10 artistas con más likes
top_10_likes = df_artist.sort_values(by='likes', ascending=False).head(10)

#Compruebo resultados
top_10_views
top_10_likes
# Out:
#                         views       likes
# artist
# BTS              5.607867e+08  13940380.8
# BLACKPINK        9.392962e+08  13230250.5
# Charlie Puth     1.216759e+09   8633692.5
# Ed Sheeran       1.546021e+09   8354331.9
# Justin Bieber    1.099106e+09   7858434.8
# Billie Eilish    4.821569e+08   7333853.7
# Imagine Dragons  9.093785e+08   7227447.7
# Alan Walker      7.256847e+08   6797770.2
# DJ Snake         9.180268e+08   6777583.1
# Luis Fonsi       1.162811e+09   6690848.9
